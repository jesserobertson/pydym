# %%
# %pylab inline

from scipy.io import loadmat, whosmat
import os

os.listdir('.')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ['screech.mat', 'cylinder.mat', 'Untitled0.ipynb', '.ipynb_checkpoints']

# %%
screech = whosmat('screech.mat')
cylinder = loadmat('cylinder.mat')

# %%
figure(figsize=(11, 11))
ax = subplot(1, 3, 1)
ax.imshow(cylinder['UstarX1'], interpolation='none')
ax.set_aspect('equal')
ax.set_axis_off()
ax = subplot(1, 3, 2)
ax.imshow(cylinder['S'], interpolation='none')
ax.set_aspect('equal')
ax.set_axis_off()
ax = subplot(1, 3, 3)
ax.imshow(cylinder['V'], interpolation='none')
ax.set_aspect('equal')
ax.set_axis_off()
