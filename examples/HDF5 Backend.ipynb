# %%
# %pylab inline

import h5py, pydym, os
print pydym.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0.0.2a.dev1

# %%
current_dir = os.getcwd()
data_dir = os.path.join(current_dir, 'test_data')

# %%
f = h5py.File('test_data/chaos-1.0.256.10.hdf5')

# %%
f['properties']['shape'][()]
# Out:
# array([6240,  601])

# %%
xs = f['position/x']
ys = f['position/y']
us = f['velocity/x']
vs = f['velocity/y']

# %%
figure(figsize=(11, 11))
ax = gca()
ax.quiver(xs[::5], ys[::5], us[::5, 10], vs[::5, 10])
ax.set_axis_off()
ax.set_aspect('equal')

# %%
data = pydym.FlowData('test_data/chaos-1.0.256.10.hdf5')

# %%
data['modes'].v
# Out:
# <HDF5 group "/modes" (4 members)>

# %%
pydym.plotting.plot_flow_data(data[10])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5eadeac75c61> in <module>()
# ----> 1 pydym.plotting.plot_flow_data(data[10])
#
# /home/jess/developer/pydym/pydym/flow_data.py in __getitem__(self, value_or_key)
#     166                 for dim_idx in range(self.n_dimensions):
#     167                     key = vector + '/' + self.axis_labels[dim_idx]
# --> 168                     vec_data[dim_idx] = self[key][:, idx]
#     169                 setattr(datum, vector, vec_data)
#     170
#
# /home/jess/developer/pydym/pydym/flow_data.py in __getitem__(self, value_or_key)
#     178                 return self._file[value_or_key]
#     179             except KeyError:
# --> 180                 raise KeyError("Can't find item {0}".format(value_or_key))
#     181
#     182
#
# KeyError: "Can't find item modes/x"

# %%
S, U, sigma, Vstar = pydym.dynamic_decomposition(data, return_svd=True)
evals, eigvecs = numpy.linalg.eig(S)

modes = numpy.dot(U, eigvecs)

# %%
from pydym import FlowDatum

mode_idx = 2
mode = FlowDatum(xs=data['position/y'], 
                 ys=data['position/x'], 
                 us=modes[::2, mode_idx], 
                 vs=modes[1::2, mode_idx])
fig = figure(figsize=(11, 11))
ax = gca()
ax.quiver(mode.position[0], mode.position[1], mode.velocity[0], mode.velocity[1])
ax.set_aspect('equal')
ax.set_axis_off()
fig.tight_layout()

# %%
xs, ys, us = mode.interpolate('velocity', 'x')
_,  _,  vs = mode.interpolate('velocity', 'y')
dx, dy = xs[1] - xs[0], ys[1] - ys[0]
du = numpy.gradient(us, dx, dy)
dv = numpy.gradient(vs, dx, dy)
dudxx = numpy.gradient()

# %%
figure(figsize=(11, 11))
subplot(2, 2, 1)
contourf(xs, ys, du[0], 20)
title('du/dx')
subplot(2, 2, 2)
contourf(xs, ys, du[1], 20)
title('du/dy')
subplot(2, 2, 3)
contourf(xs, ys, dv[0], 20)
title('dv/dx')
subplot(2, 2, 4)
contourf(xs, ys, dv[1], 20)
title('dv/dy')

# %%
figure()
contourf(xs, ys, sqrt(du[0] + dv[1]))
colorbar()

# %%
from folium import Map

# %%
mymap = Map(width=100, height=600, tiles="Stamen Terrain")
